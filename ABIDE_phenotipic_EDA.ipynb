# %% [markdown]
# <a href="https://colab.research.google.com/github/matheo-angelo/IC/blob/main/ABIDE_phenotipic_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ABIDE I: Análise Exploratória de Dados
#
# O objetivo deste documento é analisar os dados fenotípicos da base ABIDE, para observar como podem ser usados em predições futuras, bem como quais informações podem ser obtidas sobre o conjunto de pacientes estudados.

# %%
def get_data_path():
    try:
        import google.colab
        return '/content/drive/MyDrive/IC/ABIDE I/Phenotypic_data.csv'
    except ImportError:
        return 'project_data/Phenotypic_data.csv'

# %%
import pandas as pd

fenotipos = pd.read_csv(get_data_path())
fenotipos
# Out:
#       SITE_ID  SUB_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  SEX  \
# 0     CALTECH   51456         1          4        55.40    1
# 1     CALTECH   51457         1          4        22.90    1
# 2     CALTECH   51458         1          1        39.20    1
# 3     CALTECH   51459         1          1        22.80    1
# 4     CALTECH   51460         1          1        34.60    2
# ...       ...     ...       ...        ...          ...  ...
# 1107     YALE   50624         1          3        11.08    2
# 1108     YALE   50625         1          3         7.00    1
# 1109     YALE   50626         1          3        11.08    1
# 1110     YALE   50627         1          3         9.50    2
# 1111     YALE   50628         1          3        14.42    1
#
#      HANDEDNESS_CATEGORY  HANDEDNESS_SCORES    FIQ    VIQ  ...  \
# 0                      R                NaN  126.0  118.0  ...
# 1                   Ambi                NaN  107.0  119.0  ...
# ...

# %% [markdown]
# Como podemos ver, há 1112 pacientes analisados, e para cada um deles, há 73 colunas de dados fenotípicos, e uma mostrando o ponto de coleta dos dados.

# %%
pd.set_option('display.max_columns', None)
fenotipos.describe()
# Out:
#              SUB_ID     DX_GROUP    DSM_IV_TR  AGE_AT_SCAN          SEX  \
# count   1112.000000  1112.000000  1112.000000  1112.000000  1112.000000
# mean   50752.684353     1.515288  -646.819245    17.048864     1.147482
# std      447.680666     0.499991  2461.828856     8.036419     0.354745
# min    50002.000000     1.000000 -9999.000000     6.470000     1.000000
# 25%    50354.750000     1.000000     0.000000    11.658575     1.000000
# 50%    50724.500000     2.000000     0.000000    14.660000     1.000000
# 75%    51153.250000     2.000000     1.000000    20.085000     1.000000
# max    51607.000000     2.000000     4.000000    64.000000     2.000000
#
#        HANDEDNESS_SCORES          FIQ          VIQ          PIQ  \
# count         370.000000  1077.000000   935.000000   953.000000
# mean         -102.560892  -238.854968   -86.757219  -126.663169
# std          1273.177790  1841.858322  1389.584584  1518.469557
# ...

# %%
fenotipos.shape
# Out:
# (1112, 74)

# %%
fenotipos['SEX'].value_counts()
# Out:
# SEX
# 1    948
# 2    164
# Name: count, dtype: int64

# %% [markdown]
# Vemos que os dados do sexo biológico estão bastante desbalanceados entre "1" e "2" (que devem ser "masculino" e "feminino", respectivamente).

# %%
pd.set_option('display.max_rows', None)
fenotipos.isnull().sum()
# Out:
# SITE_ID                               0
# SUB_ID                                0
# DX_GROUP                              0
# DSM_IV_TR                             0
# AGE_AT_SCAN                           0
# SEX                                   0
# HANDEDNESS_CATEGORY                 315
# HANDEDNESS_SCORES                   742
# FIQ                                  35
# VIQ                                 177
# PIQ                                 159
# FIQ_TEST_TYPE                       165
# VIQ_TEST_TYPE                       278
# PIQ_TEST_TYPE                       259
# ADI_R_SOCIAL_TOTAL_A                700
# ADI_R_VERBAL_TOTAL_BV               700
# ADI_RRB_TOTAL_C                     700
# ADI_R_ONSET_TOTAL_D                 781
# ADI_R_RSRCH_RELIABLE                701
# ADOS_MODULE                         577
# ADOS_TOTAL                          670
# ADOS_COMM                           695
# ADOS_SOCIAL                         695
# ...

# %% [markdown]
# O conjunto de dados tem uma quantidade bastante expressiva de dados faltantes, mas essa ausência de dados está concentrada nas colunas dos testes neuropsicológicos, pois cada ponto de coleta escolheu o seu próprio conjunto de testes para avaliar o diagnóstico de TEA nos voluntários.
