# %% [markdown]
# # BrainGNN
# A Python Notebook that trains the [BrainGNN](https://www.sciencedirect.com/science/article/pii/S1361841521002784) neural network on autism fMRI data sourced from [ABIDE I](https://fcon_1000.projects.nitrc.org/indi/abide/abide_I.html) on Google Colab. The necessary dependencies might change as the code gets outdated.
#
# The original code itself is very outdated and not immediately replicable, so we had to use a more recent fork repository instead, and install additional packages by hand.

# %%
# !git clone https://github.com/MagisV/BrainGNN_Pytorch BrainGNN
# Out:
# Cloning into 'BrainGNN'...
# remote: Enumerating objects: 5281, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 5281 (delta 9), reused 6 (delta 6), pack-reused 5261 (from 3)
# Receiving objects: 100% (5281/5281), 1.29 GiB | 31.17 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# Updating files: 100% (4170/4170), done.

# %%
# !pip install torch-scatter torch-sparse torch-cluster torch-spline-conv -f https://data.pyg.org/whl/torch-2.1.1+cu121.html
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.1.1+cu121.html
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcu121/torch_scatter-2.1.2%2Bpt21cu121-cp311-cp311-linux_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 108.7 MB/s eta 0:00:00
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcu121/torch_sparse-0.6.18%2Bpt21cu121-cp311-cp311-linux_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 108.5 MB/s eta 0:00:00
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcu121/torch_cluster-1.6.3%2Bpt21cu121-cp311-cp311-linux_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 101.7 MB/s eta 0:00:00
# Collecting torch-spline-conv
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcu121/torch_spline_conv-1.2.2%2Bpt21cu121-cp311-cp311-linux_x86_64.whl (935 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 936.0/936.0 kB 62.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from torch-sparse) (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from scipy->torch-sparse) (1.26.2)
# Installing collected packages: torch-spline-conv, torch-scatter, torch-sparse, torch-cluster
# Successfully installed torch-cluster-1.6.3+pt21cu121 torch-scatter-2.1.2+pt21cu121 torch-sparse-0.6.18+pt21cu121 torch-spline-conv-1.2.2+pt21cu121

# %%
# !pip install -r /content/BrainGNN/requirements.txt
# Out:
# Collecting absl-py==2.0.0 (from -r /content/BrainGNN/requirements.txt (line 1))
#   Downloading absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting blosc2==2.3.1 (from -r /content/BrainGNN/requirements.txt (line 2))
#   Downloading blosc2-2.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting cachetools==5.3.2 (from -r /content/BrainGNN/requirements.txt (line 3))
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting certifi==2023.11.17 (from -r /content/BrainGNN/requirements.txt (line 4))
#   Downloading certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer==3.3.2 (from -r /content/BrainGNN/requirements.txt (line 5))
#   Downloading charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting deepdish==0.3.7 (from -r /content/BrainGNN/requirements.txt (line 6))
#   Downloading deepdish-0.3.7-py2.py3-none-any.whl.metadata (856 bytes)
# Collecting filelock==3.13.1 (from -r /content/BrainGNN/requirements.txt (line 7))
#   Downloading filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting fsspec==2023.10.0 (from -r /content/BrainGNN/requirements.txt (line 8))
#   Downloading fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting google-auth==2.23.4 (from -r /content/BrainGNN/requirements.txt (line 9))
#   Downloading google_auth-2.23.4-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib==1.1.0 (from -r /content/BrainGNN/requirements.txt (line 10))
#   Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting grpcio==1.59.3 (from -r /content/BrainGNN/requirements.txt (line 11))
#   Downloading grpcio-1.59.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting h5py==3.10.0 (from -r /content/BrainGNN/requirements.txt (line 12))
#   Downloading h5py-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting idna==3.6 (from -r /content/BrainGNN/requirements.txt (line 13))
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting importlib-metadata==6.8.0 (from -r /content/BrainGNN/requirements.txt (line 14))
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting Jinja2==3.1.2 (from -r /content/BrainGNN/requirements.txt (line 15))
#   Downloading Jinja2-3.1.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting joblib==1.3.2 (from -r /content/BrainGNN/requirements.txt (line 16))
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting lxml==4.9.3 (from -r /content/BrainGNN/requirements.txt (line 17))
#   Downloading lxml-4.9.3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting Markdown==3.5.1 (from -r /content/BrainGNN/requirements.txt (line 18))
#   Downloading Markdown-3.5.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting MarkupSafe==2.1.3 (from -r /content/BrainGNN/requirements.txt (line 19))
#   Downloading MarkupSafe-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/BrainGNN/requirements.txt (line 20)) (1.3.0)
# Collecting msgpack==1.0.7 (from -r /content/BrainGNN/requirements.txt (line 21))
#   Downloading msgpack-1.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting ndindex==1.7 (from -r /content/BrainGNN/requirements.txt (line 22))
#   Downloading ndindex-1.7-py3-none-any.whl.metadata (3.4 kB)
# Collecting networkx==3.2.1 (from -r /content/BrainGNN/requirements.txt (line 23))
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting nibabel==5.1.0 (from -r /content/BrainGNN/requirements.txt (line 24))
#   Downloading nibabel-5.1.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting nilearn==0.10.2 (from -r /content/BrainGNN/requirements.txt (line 25))
#   Downloading nilearn-0.10.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting numexpr==2.8.7 (from -r /content/BrainGNN/requirements.txt (line 26))
#   Downloading numexpr-2.8.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Collecting numpy==1.26.2 (from -r /content/BrainGNN/requirements.txt (line 27))
#   Downloading numpy-1.26.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: oauthlib==3.2.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/BrainGNN/requirements.txt (line 28)) (3.2.2)
# Collecting packaging==23.2 (from -r /content/BrainGNN/requirements.txt (line 29))
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pandas==2.1.3 (from -r /content/BrainGNN/requirements.txt (line 30))
#   Downloading pandas-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting Pillow==10.1.0 (from -r /content/BrainGNN/requirements.txt (line 31))
#   Downloading Pillow-10.1.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting protobuf==4.23.4 (from -r /content/BrainGNN/requirements.txt (line 32))
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# Collecting psutil==5.9.6 (from -r /content/BrainGNN/requirements.txt (line 33))
#   Downloading psutil-5.9.6-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: py-cpuinfo==9.0.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/BrainGNN/requirements.txt (line 34)) (9.0.0)
# Collecting pyasn1==0.5.1 (from -r /content/BrainGNN/requirements.txt (line 35))
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting pyasn1-modules==0.3.0 (from -r /content/BrainGNN/requirements.txt (line 36))
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting pyparsing==3.1.1 (from -r /content/BrainGNN/requirements.txt (line 37))
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/BrainGNN/requirements.txt (line 38)) (2.8.2)
# Collecting pytz==2023.3.post1 (from -r /content/BrainGNN/requirements.txt (line 39))
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests==2.31.0 (from -r /content/BrainGNN/requirements.txt (line 40))
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests-oauthlib==1.3.1 (from -r /content/BrainGNN/requirements.txt (line 41))
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: rsa==4.9 in /usr/local/lib/python3.11/dist-packages (from -r /content/BrainGNN/requirements.txt (line 42)) (4.9)
# Collecting scikit-learn==1.3.2 (from -r /content/BrainGNN/requirements.txt (line 43))
#   Downloading scikit_learn-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting scipy==1.11.4 (from -r /content/BrainGNN/requirements.txt (line 44))
#   Downloading scipy-1.11.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 5.5 MB/s eta 0:00:00
# Collecting six==1.16.0 (from -r /content/BrainGNN/requirements.txt (line 45))
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting sympy==1.12 (from -r /content/BrainGNN/requirements.txt (line 46))
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting tables==3.9.2 (from -r /content/BrainGNN/requirements.txt (line 47))
#   Downloading tables-3.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting tensorboard==2.15.1 (from -r /content/BrainGNN/requirements.txt (line 48))
#   Downloading tensorboard-2.15.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tensorboard-data-server==0.7.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/BrainGNN/requirements.txt (line 49)) (0.7.2)
# Collecting tensorboardX==2.6.2.2 (from -r /content/BrainGNN/requirements.txt (line 50))
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting threadpoolctl==3.2.0 (from -r /content/BrainGNN/requirements.txt (line 51))
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting torch==2.1.1 (from -r /content/BrainGNN/requirements.txt (line 52))
#   Downloading torch-2.1.1-cp311-cp311-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting torch-tb-profiler==0.4.3 (from -r /content/BrainGNN/requirements.txt (line 53))
#   Downloading torch_tb_profiler-0.4.3-py3-none-any.whl.metadata (1.4 kB)
# Collecting torch_geometric==2.4.0 (from -r /content/BrainGNN/requirements.txt (line 54))
#   Downloading torch_geometric-2.4.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 6.0 MB/s eta 0:00:00
# Collecting torchaudio==2.1.1 (from -r /content/BrainGNN/requirements.txt (line 55))
#   Downloading torchaudio-2.1.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting torchvision==0.16.1 (from -r /content/BrainGNN/requirements.txt (line 56))
#   Downloading torchvision-0.16.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting tqdm==4.66.1 (from -r /content/BrainGNN/requirements.txt (line 57))
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.7 MB/s eta 0:00:00
# Collecting typing_extensions==4.8.0 (from -r /content/BrainGNN/requirements.txt (line 58))
#   Downloading typing_extensions-4.8.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting tzdata==2023.3 (from -r /content/BrainGNN/requirements.txt (line 59))
#   Downloading tzdata-2023.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting urllib3==2.1.0 (from -r /content/BrainGNN/requirements.txt (line 60))
#   Downloading urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting Werkzeug==3.0.1 (from -r /content/BrainGNN/requirements.txt (line 61))
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting zipp==3.17.0 (from -r /content/BrainGNN/requirements.txt (line 62))
#   Downloading zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard==2.15.1->-r /content/BrainGNN/requirements.txt (line 48)) (75.2.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.1.1->-r /content/BrainGNN/requirements.txt (line 52))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.1.1->-r /content/BrainGNN/requirements.txt (line 52))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.1.1->-r /content/BrainGNN/requirements.txt (line 52))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.1.1->-r /content/BrainGNN/requirements.txt (line 52))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.1.1->-r /content/BrainGNN/requirements.txt (line 52))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.1.1->-r /content/BrainGNN/requirements.txt (line 52))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.1.1->-r /content/BrainGNN/requirements.txt (line 52))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.1.1->-r /content/BrainGNN/requirements.txt (line 52))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.1.1->-r /content/BrainGNN/requirements.txt (line 52))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.18.1 (from torch==2.1.1->-r /content/BrainGNN/requirements.txt (line 52))
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.1.1->-r /content/BrainGNN/requirements.txt (line 52))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.1.0 (from torch==2.1.1->-r /content/BrainGNN/requirements.txt (line 52))
#   Downloading triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.1->-r /content/BrainGNN/requirements.txt (line 52)) (12.5.82)
# Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 13.1 MB/s eta 0:00:00
# Downloading blosc2-2.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 72.0 MB/s eta 0:00:00
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading certifi-2023.11.17-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 16.5 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.3/140.3 kB 14.6 MB/s eta 0:00:00
# Downloading deepdish-0.3.7-py2.py3-none-any.whl (37 kB)
# Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Downloading fsspec-2023.10.0-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 16.0 MB/s eta 0:00:00
# Downloading google_auth-2.23.4-py2.py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.3/183.3 kB 17.1 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl (19 kB)
# Downloading grpcio-1.59.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 92.8 MB/s eta 0:00:00
# Downloading h5py-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 110.7 MB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.6 MB/s eta 0:00:00
# Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 12.6 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 27.6 MB/s eta 0:00:00
# Downloading lxml-4.9.3-cp311-cp311-manylinux_2_28_x86_64.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 116.6 MB/s eta 0:00:00
# Downloading Markdown-3.5.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 9.9 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading msgpack-1.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (557 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.0/558.0 kB 43.2 MB/s eta 0:00:00
# Downloading ndindex-1.7-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 9.1 MB/s eta 0:00:00
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.2 MB/s eta 0:00:00
# Downloading nibabel-5.1.0-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 102.3 MB/s eta 0:00:00
# Downloading nilearn-0.10.2-py3-none-any.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 33.4 MB/s eta 0:00:00
# Downloading numexpr-2.8.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.4/386.4 kB 32.0 MB/s eta 0:00:00
# Downloading numpy-1.26.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 100.4 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.7 MB/s eta 0:00:00
# Downloading pandas-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 117.6 MB/s eta 0:00:00
# Downloading Pillow-10.1.0-cp311-cp311-manylinux_2_28_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 101.7 MB/s eta 0:00:00
# Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 26.5 MB/s eta 0:00:00
# Downloading psutil-5.9.6-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.6/283.6 kB 25.1 MB/s eta 0:00:00
# Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 8.2 MB/s eta 0:00:00
# Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 17.2 MB/s eta 0:00:00
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 10.4 MB/s eta 0:00:00
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 41.7 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 6.7 MB/s eta 0:00:00
# Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Downloading scikit_learn-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 71.9 MB/s eta 0:00:00
# Downloading scipy-1.11.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 13.2 MB/s eta 0:00:00
# Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 118.1 MB/s eta 0:00:00
# Downloading tables-3.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 35.5 MB/s eta 0:00:00
# Downloading tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 106.0 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 8.8 MB/s eta 0:00:00
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Downloading torch-2.1.1-cp311-cp311-manylinux1_x86_64.whl (670.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.8 MB/s eta 0:00:00
# Downloading torch_tb_profiler-0.4.3-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.8 MB/s eta 0:00:00
# Downloading torch_geometric-2.4.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.0 MB/s eta 0:00:00
# Downloading torchaudio-2.1.1-cp311-cp311-manylinux1_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 100.2 MB/s eta 0:00:00
# Downloading torchvision-0.16.1-cp311-cp311-manylinux1_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 105.0 MB/s eta 0:00:00
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 8.1 MB/s eta 0:00:00
# Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 27.9 MB/s eta 0:00:00
# Downloading urllib3-2.1.0-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 10.4 MB/s eta 0:00:00
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 21.8 MB/s eta 0:00:00
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 95.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 81.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 50.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.4 MB/s eta 0:00:00
# Downloading triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 8.2 MB/s eta 0:00:00
# Installing collected packages: pytz, zipp, urllib3, tzdata, typing_extensions, tqdm, threadpoolctl, sympy, six, pyparsing, pyasn1, psutil, protobuf, Pillow, packaging, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, ndindex, msgpack, MarkupSafe, Markdown, lxml, joblib, idna, grpcio, fsspec, filelock, charset-normalizer, certifi, cachetools, absl-py, Werkzeug, triton, tensorboardX, scipy, requests, pyasn1-modules, nvidia-cusolver-cu12, nvidia-cudnn-cu12, numexpr, nibabel, Jinja2, importlib-metadata, h5py, blosc2, torch, tables, scikit-learn, requests-oauthlib, pandas, google-auth, torchvision, torchaudio, torch_geometric, nilearn, google-auth-oauthlib, deepdish, tensorboard, torch-tb-profiler
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.21.0
#     Uninstalling zipp-3.21.0:
#       Successfully uninstalled zipp-3.21.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.13.1
#     Uninstalling typing_extensions-4.13.1:
#       Successfully uninstalled typing_extensions-4.13.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.6.0
#     Uninstalling threadpoolctl-3.6.0:
#       Successfully uninstalled threadpoolctl-3.6.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.2.3
#     Uninstalling pyparsing-3.2.3:
#       Successfully uninstalled pyparsing-3.2.3
#   Attempting uninstall: pyasn1
#     Found existing installation: pyasn1 0.6.1
#     Uninstalling pyasn1-0.6.1:
#       Successfully uninstalled pyasn1-0.6.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: ndindex
#     Found existing installation: ndindex 1.9.2
#     Uninstalling ndindex-1.9.2:
#       Successfully uninstalled ndindex-1.9.2
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.1.0
#     Uninstalling msgpack-1.1.0:
#       Successfully uninstalled msgpack-1.1.0
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: Markdown
#     Found existing installation: Markdown 3.7
#     Uninstalling Markdown-3.7:
#       Successfully uninstalled Markdown-3.7
#   Attempting uninstall: lxml
#     Found existing installation: lxml 5.3.1
#     Uninstalling lxml-5.3.1:
#       Successfully uninstalled lxml-5.3.1
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.71.0
#     Uninstalling grpcio-1.71.0:
#       Successfully uninstalled grpcio-1.71.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.18.0
#     Uninstalling filelock-3.18.0:
#       Successfully uninstalled filelock-3.18.0
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.4.1
#     Uninstalling charset-normalizer-3.4.1:
#       Successfully uninstalled charset-normalizer-3.4.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.1.31
#     Uninstalling certifi-2025.1.31:
#       Successfully uninstalled certifi-2025.1.31
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.5.2
#     Uninstalling cachetools-5.5.2:
#       Successfully uninstalled cachetools-5.5.2
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: pyasn1-modules
#     Found existing installation: pyasn1_modules 0.4.2
#     Uninstalling pyasn1_modules-0.4.2:
#       Successfully uninstalled pyasn1_modules-0.4.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: numexpr
#     Found existing installation: numexpr 2.10.2
#     Uninstalling numexpr-2.10.2:
#       Successfully uninstalled numexpr-2.10.2
#   Attempting uninstall: nibabel
#     Found existing installation: nibabel 5.3.2
#     Uninstalling nibabel-5.3.2:
#       Successfully uninstalled nibabel-5.3.2
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.6.1
#     Uninstalling importlib_metadata-8.6.1:
#       Successfully uninstalled importlib_metadata-8.6.1
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.13.0
#     Uninstalling h5py-3.13.0:
#       Successfully uninstalled h5py-3.13.0
#   Attempting uninstall: blosc2
#     Found existing installation: blosc2 3.2.1
#     Uninstalling blosc2-3.2.1:
#       Successfully uninstalled blosc2-3.2.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: tables
#     Found existing installation: tables 3.10.2
#     Uninstalling tables-3.10.2:
#       Successfully uninstalled tables-3.10.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: requests-oauthlib
#     Found existing installation: requests-oauthlib 2.0.0
#     Uninstalling requests-oauthlib-2.0.0:
#       Successfully uninstalled requests-oauthlib-2.0.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.38.0
#     Uninstalling google-auth-2.38.0:
#       Successfully uninstalled google-auth-2.38.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.6.0+cu124
#     Uninstalling torchaudio-2.6.0+cu124:
#       Successfully uninstalled torchaudio-2.6.0+cu124
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.1
#     Uninstalling google-auth-oauthlib-1.2.1:
#       Successfully uninstalled google-auth-oauthlib-1.2.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.18.0
#     Uninstalling tensorboard-2.18.0:
#       Successfully uninstalled tensorboard-2.18.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.23.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.31.0 which is incompatible.
# flask 3.1.0 requires Werkzeug>=3.1, but you have werkzeug 3.0.1 which is incompatible.
# pytensor 2.30.2 requires filelock>=3.15, but you have filelock 3.13.1 which is incompatible.
# typeguard 4.4.2 requires typing_extensions>=4.10.0, but you have typing-extensions 4.8.0 which is incompatible.
# altair 5.5.0 requires typing-extensions>=4.10.0; python_version < "3.14", but you have typing-extensions 4.8.0 which is incompatible.
# tensorflow 2.18.0 requires h5py>=3.11.0, but you have h5py 3.10.0 which is incompatible.
# tensorflow 2.18.0 requires tensorboard<2.19,>=2.18, but you have tensorboard 2.15.1 which is incompatible.
# typing-inspection 0.4.0 requires typing-extensions>=4.12.0, but you have typing-extensions 4.8.0 which is incompatible.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.23.4 which is incompatible.
# grpcio-status 1.71.0 requires grpcio>=1.71.0, but you have grpcio 1.59.3 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.23.4 which is incompatible.
# openai 1.70.0 requires typing-extensions<5,>=4.11, but you have typing-extensions 4.8.0 which is incompatible.
# google-cloud-storage 2.19.0 requires google-auth<3.0dev,>=2.26.1, but you have google-auth 2.23.4 which is incompatible.
# mizani 0.13.2 requires pandas>=2.2.0, but you have pandas 2.1.3 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.2 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2023.10.0 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 2.1.3 which is incompatible.
# google-genai 1.9.0 requires typing-extensions<5.0.0,>=4.11.0, but you have typing-extensions 4.8.0 which is incompatible.
# google-cloud-bigquery 3.31.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# pydantic 2.11.2 requires typing-extensions>=4.12.2, but you have typing-extensions 4.8.0 which is incompatible.
# tensorflow-metadata 1.17.0 requires protobuf<6.0.0,>=4.25.2; python_version >= "3.11", but you have protobuf 4.23.4 which is incompatible.
# Successfully installed Jinja2-3.1.2 Markdown-3.5.1 MarkupSafe-2.1.3 Pillow-10.1.0 Werkzeug-3.0.1 absl-py-2.0.0 blosc2-2.3.1 cachetools-5.3.2 certifi-2023.11.17 charset-normalizer-3.3.2 deepdish-0.3.7 filelock-3.13.1 fsspec-2023.10.0 google-auth-2.23.4 google-auth-oauthlib-1.1.0 grpcio-1.59.3 h5py-3.10.0 idna-3.6 importlib-metadata-6.8.0 joblib-1.3.2 lxml-4.9.3 msgpack-1.0.7 ndindex-1.7 networkx-3.2.1 nibabel-5.1.0 nilearn-0.10.2 numexpr-2.8.7 numpy-1.26.2 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvtx-cu12-12.1.105 packaging-23.2 pandas-2.1.3 protobuf-4.23.4 psutil-5.9.6 pyasn1-0.5.1 pyasn1-modules-0.3.0 pyparsing-3.1.1 pytz-2023.3.post1 requests-2.31.0 requests-oauthlib-1.3.1 scikit-learn-1.3.2 scipy-1.11.4 six-1.16.0 sympy-1.12 tables-3.9.2 tensorboard-2.15.1 tensorboardX-2.6.2.2 threadpoolctl-3.2.0 torch-2.1.1 torch-tb-profiler-0.4.3 torch_geometric-2.4.0 torchaudio-2.1.1 torchvision-0.16.1 tqdm-4.66.1 triton-2.1.0 typing_extensions-4.8.0 tzdata-2023.3 urllib3-2.1.0 zipp-3.17.0

# %%
# %run /content/BrainGNN/01-fetch_data.py
# %run /content/BrainGNN/02-process_data.py
# %run /content/BrainGNN/03-main.py
# Out:
# Processing...
# Time:  147.4000143369999
# Done!
# Network(
#   (n1): Sequential(
#     (0): Linear(in_features=200, out_features=8, bias=False)
#     (1): ReLU()
#     (2): Linear(in_features=8, out_features=6400, bias=True)
#   )
#   (conv1): MyNNConv(200, 32)
#   (pool1): TopKPooling(32, ratio=0.5, multiplier=1)
#   (n2): Sequential(
#     (0): Linear(in_features=200, out_features=8, bias=False)
#     (1): ReLU()
#     (2): Linear(in_features=8, out_features=1024, bias=True)
#   )
#   (conv2): MyNNConv(32, 32)
#   (pool2): TopKPooling(32, ratio=0.5, multiplier=1)
#   (fc1): Linear(in_features=128, out_features=32, bias=True)
#   (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=32, out_features=512, bias=True)
#   (bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=512, out_features=2, bias=True)
# )
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 5s
# Epoch: 000, Train Loss: 1.2830698, Train Acc: 0.5330113, Test Loss: 1.0657416, Test Acc: 0.4927536
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 001, Train Loss: 1.3310292, Train Acc: 0.5346216, Test Loss: 1.5643550, Test Acc: 0.4975845
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 002, Train Loss: 1.2714066, Train Acc: 0.5330113, Test Loss: 2.7619766, Test Acc: 0.4879227
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 003, Train Loss: 1.3162696, Train Acc: 0.5362319, Test Loss: 1.2434744, Test Acc: 0.5024155
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 004, Train Loss: 1.2459584, Train Acc: 0.5362319, Test Loss: 1.3614087, Test Acc: 0.5024155
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 005, Train Loss: 1.2132220, Train Acc: 0.4524960, Test Loss: 1.0281104, Test Acc: 0.5217391
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 006, Train Loss: 1.1204866, Train Acc: 0.4669887, Test Loss: 1.0210932, Test Acc: 0.5169082
# saving best model
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 007, Train Loss: 1.1758895, Train Acc: 0.5297907, Test Loss: 1.1197637, Test Acc: 0.4685990
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 008, Train Loss: 1.0486153, Train Acc: 0.5346216, Test Loss: 1.0142081, Test Acc: 0.4734300
# saving best model
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 009, Train Loss: 1.0871065, Train Acc: 0.5330113, Test Loss: 0.9803880, Test Acc: 0.4927536
# saving best model
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 010, Train Loss: 1.1124842, Train Acc: 0.4685990, Test Loss: 1.0170076, Test Acc: 0.5072464
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 011, Train Loss: 1.0309354, Train Acc: 0.5523349, Test Loss: 0.9888714, Test Acc: 0.4830918
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 012, Train Loss: 1.0168786, Train Acc: 0.5652174, Test Loss: 0.9896691, Test Acc: 0.4830918
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 013, Train Loss: 1.0142557, Train Acc: 0.4734300, Test Loss: 0.9773478, Test Acc: 0.5072464
# saving best model
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 014, Train Loss: 1.0207821, Train Acc: 0.5587762, Test Loss: 1.0082643, Test Acc: 0.5169082
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 015, Train Loss: 1.0080503, Train Acc: 0.5362319, Test Loss: 0.9881922, Test Acc: 0.4975845
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 016, Train Loss: 0.9924520, Train Acc: 0.4669887, Test Loss: 1.0172587, Test Acc: 0.5072464
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 017, Train Loss: 0.9877216, Train Acc: 0.4685990, Test Loss: 1.0069016, Test Acc: 0.5072464
# train...........
# LR 0.01
# testing...........
# *====**
# 0m 3s
# Epoch: 018, Train Loss: 0.9618896, Train Acc: 0.4669887, Test Loss: 1.0254303, Test Acc: 0.5072464
# train...........
# LR 0.005
# testing...........
# *====**
# 0m 3s
# Epoch: 019, Train Loss: 0.9071981, Train Acc: 0.5314010, Test Loss: 0.9737340, Test Acc: 0.5410628
# saving best model
# train...........
# LR 0.005
# testing...........
# *====**
# 0m 3s
# Epoch: 020, Train Loss: 0.8856562, Train Acc: 0.5652174, Test Loss: 0.9656951, Test Acc: 0.5507246
# saving best model
# train...........
# LR 0.005
# testing...........
# *====**
# 0m 3s
# Epoch:
# train...........
# LR 0.00125
# testing...........
# *====**
# 0m 3s
# Epoch: 077, Train Loss: 0.5886784, Train Acc: 0.8260870, Test Loss: 1.3135432, Test Acc: 0.5507246
# train...........
# LR 0.00125
# testing...........
# *====**
# 0m 3s
# Epoch: 078, Train Loss: 0.6076902, Train Acc: 0.8051530, Test Loss: 1.6770296, Test Acc: 0.5410628
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 079, Train Loss: 0.5826786, Train Acc: 0.7487923, Test Loss: 2.2183218, Test Acc: 0.5362319
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 080, Train Loss: 0.6003654, Train Acc: 0.8631240, Test Loss: 1.4692085, Test Acc: 0.5265700
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 081, Train Loss: 0.5738726, Train Acc: 0.8341385, Test Loss: 1.1590762, Test Acc: 0.5217391
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 082, Train Loss: 0.5692494, Train Acc: 0.8743961, Test Loss: 1.3556700, Test Acc: 0.5265700
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 083, Train Loss: 0.5584619, Train Acc: 0.7826087, Test Loss: 1.5299532, Test Acc: 0.5169082
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 084, Train Loss: 0.5539381, Train Acc: 0.8888889, Test Loss: 1.4367260, Test Acc: 0.5265700
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 4s
# Epoch: 085, Train Loss: 0.5507990, Train Acc: 0.8486312, Test Loss: 1.1965464, Test Acc: 0.5362319
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 086, Train Loss: 0.5569769, Train Acc: 0.8566828, Test Loss: 1.8546054, Test Acc: 0.5507246
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 087, Train Loss: 0.5589868, Train Acc: 0.8792271, Test Loss: 1.5345735, Test Acc: 0.5314010
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 088, Train Loss: 0.5656347, Train Acc: 0.8743961, Test Loss: 1.6281091, Test Acc: 0.5314010
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 089, Train Loss: 0.5718395, Train Acc: 0.7954911, Test Loss: 1.3609541, Test Acc: 0.5169082
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 090, Train Loss: 0.5837105, Train Acc: 0.8824477, Test Loss: 1.6711613, Test Acc: 0.5362319
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 091, Train Loss: 0.5543996, Train Acc: 0.7359098, Test Loss: 2.2796510, Test Acc: 0.5314010
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 092, Train Loss: 0.5584600, Train Acc: 0.8421900, Test Loss: 1.8650627, Test Acc: 0.5507246
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 093, Train Loss: 0.5429742, Train Acc: 0.8196457, Test Loss: 2.0050064, Test Acc: 0.5507246
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 094, Train Loss: 0.5533620, Train Acc: 0.7600644, Test Loss: 1.2589326, Test Acc: 0.5217391
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 095, Train Loss: 0.5586323, Train Acc: 0.9082126, Test Loss: 1.5563721, Test Acc: 0.5410628
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 096, Train Loss: 0.5406853, Train Acc: 0.8454106, Test Loss: 1.9078414, Test Acc: 0.5555556
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 097, Train Loss: 0.5497566, Train Acc: 0.9194847, Test Loss: 1.6116290, Test Acc: 0.5314010
# train...........
# LR 0.000625
# testing...........
# *====**
# 0m 3s
# Epoch: 098, Train Loss: 0.5333666, Train Acc: 0.8904992, Test Loss: 1.4389153, Test Acc: 0.5120773
# train...........
# LR 0.0003125
# testing...........
# *====**
# 0m 3s
# Epoch: 099, Train Loss: 0.5432923, Train Acc: 0.8550725, Test Loss: 1.3079231, Test Acc: 0.5410628
# testing...........
# ===========================
# Test Acc: 0.5700483, Test Loss: 0.9508347
# Namespace(epoch=0, n_epochs=100, batchSize=100, dataroot='/content/BrainGNN/data/ABIDE_pcp/cpac/filt_noglobal', fold=0, lr=0.01, stepsize=20, gamma=0.5, weightdecay=0.005, lamb0=1, lamb1=0, lamb2=0, lamb3=0.1, lamb4=0.1, lamb5=0.1, layer=2, ratio=0.5, indim=200, nroi=200, nclass=2, load_model=False, save_model=True, optim='Adam', save_path='./model/')
