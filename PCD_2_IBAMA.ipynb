# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
import plotly.express as px

# %% [markdown]
# ### Acidente ambiental

# %% [markdown]
# 13755 rows × 70 columns

# %%
df_acidentes = pd.read_csv('http://siscom.ibama.gov.br/geoserver/publica/ows?service=WFS&version=1.0.0&request=GetFeature&typeName=publica:adm_comunicacidente_p&outputFormat=csv')
# Out:
# <ipython-input-2-9d676d2329ca>:1: DtypeWarning: Columns (11,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_acidentes = pd.read_csv('http://siscom.ibama.gov.br/geoserver/publica/ows?service=WFS&version=1.0.0&request=GetFeature&typeName=publica:adm_comunicacidente_p&outputFormat=csv')

# %%
df_acidentes.head()
# Out:
#                                                  FID  \
# 0  adm_comunicacidente_p.fid--556437c7_1936900762...
# 1  adm_comunicacidente_p.fid--556437c7_1936900762...
# 2  adm_comunicacidente_p.fid--556437c7_1936900762...
# 3  adm_comunicacidente_p.fid--556437c7_1936900762...
# 4  adm_comunicacidente_p.fid--556437c7_1936900762...
#
#                                    uuid  id_ocorrencia  id_municipio  id_uf  \
# 0  9d1f1f3a-0840-4de9-9019-f3a8cec09a72            312     2706901.0    2.0
# 1  9e1b47f8-72de-4db9-aeb2-ffc7fd52b306            313     3205309.0    8.0
# 2  7404e435-94ec-4f3a-b46d-409b0bd9b310            314     5003702.0   12.0
# 3  e6338a4d-cdc1-4bde-b037-366019617cc6            315           NaN    7.0
# 4  f1085ea1-6007-466d-a850-77d5023ad819            316     4312054.0   21.0
#
#    id_responsavel des_complemento_tipo_localizaca des_complemento_tipo_evento  \
# 0             NaN                             NaN                         NaN
# ...

# %% [markdown]
# ### Remoção de dados nulos

# %% [markdown]
# Abaixo podemos ver a lista de todas as colunas do dataset inicial.

# %%
df_acidentes.columns
# Out:
# Index(['FID', 'uuid', 'id_ocorrencia', 'id_municipio', 'id_uf',
#        'id_responsavel', 'des_complemento_tipo_localizaca',
#        'des_complemento_tipo_evento', 'des_complemento_instituicao_atu',
#        'des_complemento_tipo_dano_ident', 'des_danos', 'des_ocorrencia',
#        'dt_ocorrencia', 'hr_ocorrencia', 'dt_registro',
#        'des_informacoes_adicionais', 'plano_emergencia',
#        'plano_emergencia_acionado', 'iniciados_outras_providencias',
#        'des_outras_providencias', 'ocorrencia_oleo', 'dt_primeira_obs',
#        'hr_primeira_obs', 'informacao_geografica', 'informacao_responsavel',
#        'acao_inicial_tomada', 'des_causa_provavel', 'situacao_atual_descarga',
#        'nro_ocorrencia', 'endereco_ocorrencia', 'nome_instituicao_atuando',
#        'telefone_instituicao_atuando', 'tipo_substancia', 'volume_estimado',
#        'produto_nao_se_aplica', 'produto_perigoso', 'produto_nao_especificado',
# ...

# %% [markdown]
# Inicialmente, apagamos as colunas que possuem mais de 7000 valores nulos, bem como colunas que possuem informações omitidas pela lei de proteção de dados, informações redundantes ou informações que podem ser obtidas por meio de outras colunas.
#
# Podemos ver também a lista de todas as colunas iniciais que possuem valores nulos, e a quantidade desses valores

# %%
lista_nan = df_acidentes.columns[df_acidentes.isna().any()].tolist()
for i in lista_nan:
  quantidade_nan = df_acidentes[i].isna().sum()
  print(i, ':', quantidade_nan)
  if quantidade_nan > 7000:
    df_acidentes = df_acidentes.drop(columns=[i])

df_acidentes = df_acidentes.drop(columns=["id_responsavel", "cpf_contato", "id_municipio", "id_uf", "informacao_geografica", "ip_contato",
                                          "nro_ocorrencia", "nome_comunicante", "dt_carga", "telefone_contato", "des_funcao_comunicante",
                                          "email_comunicante", "FID", "uuid", "id_ocorrencia"])
# Out:
# id_municipio : 2688
# id_uf : 919
# id_responsavel : 6745
# des_complemento_tipo_localizaca : 9399
# des_complemento_tipo_evento : 9506
# des_complemento_instituicao_atu : 8609
# des_complemento_tipo_dano_ident : 10131
# des_danos : 13755
# des_ocorrencia : 7980
# dt_ocorrencia : 6197
# hr_ocorrencia : 645
# des_informacoes_adicionais : 13755
# plano_emergencia : 6581
# des_outras_providencias : 8328
# dt_primeira_obs : 6035
# hr_primeira_obs : 6106
# informacao_geografica : 6894
# acao_inicial_tomada : 13755
# des_causa_provavel : 6440
# situacao_atual_descarga : 11127
# endereco_ocorrencia : 6299
# nome_instituicao_atuando : 12064
# telefone_instituicao_atuando : 12261
# tipo_substancia : 12052
# volume_estimado : 12212
# produto_nao_se_aplica : 12283
# produto_perigoso : 11650
# produto_nao_especificado : 12523
# id_bacia_sedimentar : 11464
# des_instituicao_empresa : 6620
# des_obs : 7384
# cpf_contato : 5798
# tipo_comunicado : 6861
# periodo_ocorrencia : 793
# ...

# %% [markdown]
# Após a exclusão de algumas colunas, podemos ver a lista de colunas resultantes que possuem valores nulos e a quantidade desses valores em cada coluna.

# %%
lista_nan = df_acidentes.columns[df_acidentes.isna().any()].tolist()
for i in lista_nan:
  quantidade_nan = df_acidentes[i].isna().sum()
  print(i, ':', quantidade_nan)
# Out:
# dt_ocorrencia : 6197
# hr_ocorrencia : 645
# plano_emergencia : 6581
# dt_primeira_obs : 6035
# hr_primeira_obs : 6106
# des_causa_provavel : 6440
# endereco_ocorrencia : 6299
# des_instituicao_empresa : 6620
# tipo_comunicado : 6861
# periodo_ocorrencia : 793
# periodo_primeira_obs : 6269
# municipio : 2883
# uf : 953
# origem : 173
# tipo_evento : 145
# dt_ocorrencia_feriado : 5796
# institiuicoes_atuando_local : 1659
# tipos_fontes_informacoes : 343
# tipos_danos_identificados : 941

# %% [markdown]
# Abaixo vemos a lista de colunas presentes no dataset após a limpeza inicial.

# %%
df_acidentes.columns
# Out:
# Index(['dt_ocorrencia', 'hr_ocorrencia', 'dt_registro', 'plano_emergencia',
#        'plano_emergencia_acionado', 'iniciados_outras_providencias',
#        'ocorrencia_oleo', 'dt_primeira_obs', 'hr_primeira_obs',
#        'informacao_responsavel', 'des_causa_provavel', 'endereco_ocorrencia',
#        'legado', 'des_instituicao_empresa', 'validado', 'tipo_comunicado',
#        'periodo_ocorrencia', 'periodo_primeira_obs', 'municipio', 'uf',
#        'origem', 'tipo_evento', 'dt_ocorrencia_feriado',
#        'institiuicoes_atuando_local', 'tipos_fontes_informacoes',
#        'tipos_danos_identificados', 'geom'],
#       dtype='object')

# %% [markdown]
# ### Tratamento dos dados de data e hora

# %% [markdown]
# Antes de processar os dados de data/hora, devemos nos atentar a casos de registros errados. Abaixo vemos alguns exemplos de datas em que o ano começa com o número 0, o que provavelmente foi causado por falha humana no momento do registro.

# %%
test = df_acidentes['dt_ocorrencia'].to_list()
for i in test:
  if type(i) == str:
    if i[0] == '1' or i[0] == '0' or i == '2201-02-16':
      print(i)
# Out:
# 2201-02-16
# 0206-06-03
# 0016-06-22
# 0201-01-28
# 0201-07-14
# 0201-11-28
# 0201-11-29
# 1015-12-20
# 0202-11-02
# 0222-02-09
# 0202-09-22
# 0202-02-13
# 0202-04-09

# %% [markdown]
# Quando olhamos para essa observação específica, podemos ver qual seria o ano correto ao observar a coluna "dt_registro", que aparenta ser uma coluna preenchida automaticamente pelo sistema

# %%
df_acidentes.loc[df_acidentes['dt_ocorrencia'] == '0206-06-03']
# Out:
#      dt_ocorrencia hr_ocorrencia          dt_registro plano_emergencia  \
# 6616    0206-06-03         03:03  2016-06-06 08:15:58                S
#
#      plano_emergencia_acionado iniciados_outras_providencias ocorrencia_oleo  \
# 6616                         N                             S               S
#
#      dt_primeira_obs hr_primeira_obs informacao_responsavel  ...  \
# 6616      2016-06-03           03:03                      T  ...
#
#      periodo_primeira_obs municipio  uf      origem               tipo_evento  \
# 6616                    S     Macaé  RJ  Embarcação  Derramamento de líquidos
#
#      dt_ocorrencia_feriado institiuicoes_atuando_local  \
# 6616                     f                    Outra(s)
#
#                tipos_fontes_informacoes tipos_danos_identificados  \
# 6616  Comunicado da empresa/responsável                       Mar
#
#                                                 geom
# 6616  POINT (-40.02866111111111 -22.564902777777778)
#
# ...

# %% [markdown]
# Assim, após uma investigação aprofundada, achamos todos os registros com erros e substituímos pelo formato adequado, tanto para a coluna "dt_ocorrencia" quanto para a coluna "dt_primeira_obs"

# %%
df_acidentes = df_acidentes.replace('2201-02-16', '2016-02-16')
df_acidentes = df_acidentes.replace('0206-06-03', '2016-06-03')
df_acidentes = df_acidentes.replace('0016-06-22', '2016-06-22')
df_acidentes = df_acidentes.replace('0201-01-28', '2018-01-28')
df_acidentes = df_acidentes.replace('0201-07-14', '2018-07-14')
df_acidentes = df_acidentes.replace('0201-11-28', '2019-11-28')
df_acidentes = df_acidentes.replace('0201-11-29', '2019-11-29')
df_acidentes = df_acidentes.replace('0202-11-02', '2020-11-02')
df_acidentes = df_acidentes.replace('0222-02-09', '2022-02-09')
df_acidentes = df_acidentes.replace('0202-09-22', '2022-09-22')
df_acidentes = df_acidentes.replace('0202-02-13', '2023-02-13')
df_acidentes = df_acidentes.replace('0202-04-09', '2023-04-09')
df_acidentes = df_acidentes.replace('1015-12-20', '2015-12-20')

# %%
df_acidentes = df_acidentes.replace('0216-08-28', '2016-08-28')
df_acidentes = df_acidentes.replace('0216-10-15', '2016-10-15')
df_acidentes = df_acidentes.replace('0202-05-22', '2021-05-22')
df_acidentes = df_acidentes.replace('0202-01-06', '2023-01-06')
df_acidentes = df_acidentes.replace('0202-04-10', '2023-04-10')

# %% [markdown]
# O registro com formatação errada não exite mais na base

# %%
df_acidentes.loc[df_acidentes['dt_primeira_obs'] == '0202-04-10']
# Out:
# Empty DataFrame
# Columns: [dt_ocorrencia, hr_ocorrencia, dt_registro, plano_emergencia, plano_emergencia_acionado, iniciados_outras_providencias, ocorrencia_oleo, dt_primeira_obs, hr_primeira_obs, informacao_responsavel, des_causa_provavel, endereco_ocorrencia, legado, des_instituicao_empresa, validado, tipo_comunicado, periodo_ocorrencia, periodo_primeira_obs, municipio, uf, origem, tipo_evento, dt_ocorrencia_feriado, institiuicoes_atuando_local, tipos_fontes_informacoes, tipos_danos_identificados, geom]
# Index: []
#
# [0 rows x 27 columns]

# %%
df_acidentes['dt_ocorrencia']
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 13750    2023-05-18
# 13751    2023-05-16
# 13752    2023-05-15
# 13753    2023-05-17
# 13754    2023-05-20
# Name: dt_ocorrencia, Length: 13755, dtype: object

# %% [markdown]
# Agora podemos transformar as colunas de data no formato date_time para melhor manipulação e investigação dos dados

# %%
df_acidentes['dt_ocorrencia_mod'] = pd.to_datetime(df_acidentes['dt_ocorrencia'])
df_acidentes['dt_registro_mod'] = pd.to_datetime(df_acidentes['dt_registro'])
df_acidentes['dt_primeira_obs_mod'] = pd.to_datetime(df_acidentes['dt_primeira_obs'])
df_acidentes['registro_ano'] = df_acidentes['dt_registro_mod'].dt.year

# %% [markdown]
# Algo parecido ocorreu com as colunas de hora. Primeiramente, os valores em branco não estavam preenchidos com 'NaN', como em outras colunas do dataset, mas sim com uma string "NULL ", o que dificultou inicialmente o tratamento dos dados. Após identificado esse erro, todas as colunas com valor nulo foram preenchidas com NaN para melhor manuseio dos dados

# %%
df_acidentes['hr_ocorrencia'].head()
# Out:
# 0    NULL
# 1    00:00
# 2    NULL
# 3    NULL
# 4    NULL
# Name: hr_ocorrencia, dtype: object

# %%
df_acidentes = df_acidentes.replace('NULL ', float('nan'))

# %% [markdown]
# Além disso, foram identificadas diversas strings com erros nas colunas. Desta vez, como não existe outra coluna de referência para modificar os erros, esses valores foram substituídos por "NaN".

# %%
df_acidentes = df_acidentes.replace('     ', float('nan'))
df_acidentes = df_acidentes.replace('10:  ', float('nan'))
df_acidentes = df_acidentes.replace('02   ', float('nan'))
df_acidentes = df_acidentes.replace('5    ', float('nan'))
df_acidentes = df_acidentes.replace('13   ', float('nan'))
df_acidentes = df_acidentes.replace(':    ', float('nan'))
df_acidentes = df_acidentes.replace('03:  ', float('nan'))
df_acidentes = df_acidentes.replace('  :  ', float('nan'))
df_acidentes = df_acidentes.replace('8    ', float('nan'))
df_acidentes = df_acidentes.replace('20:0 ', float('nan'))
df_acidentes = df_acidentes.replace('7    ', float('nan'))
df_acidentes = df_acidentes.replace('09   ', float('nan'))
df_acidentes = df_acidentes.replace('9    ', float('nan'))
df_acidentes = df_acidentes.replace('13:0 ', float('nan'))
df_acidentes = df_acidentes.replace('14   ', float('nan'))
df_acidentes = df_acidentes.replace('0    ', float('nan'))
df_acidentes = df_acidentes.replace('21:h ', float('nan'))
df_acidentes = df_acidentes.replace('16:/0', float('nan'))

# %%
df_acidentes['hr_ocorrencia'].head()
# Out:
# 0      NaN
# 1    00:00
# 2      NaN
# 3      NaN
# 4      NaN
# Name: hr_ocorrencia, dtype: object

# %% [markdown]
# O mesmo tratamento foi feito para a coluna "hr_primeira_obs"

# %%
df_acidentes['hr_primeira_obs']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 13750    09:22
# 13751    16:23
# 13752    22:56
# 13753    09:55
# 13754    08:45
# Name: hr_primeira_obs, Length: 13755, dtype: object

# %%
df_acidentes = df_acidentes.replace('9:00 ', float('nan'))
df_acidentes = df_acidentes.replace('4    ', float('nan'))
df_acidentes = df_acidentes.replace('10:0 ', float('nan'))
df_acidentes = df_acidentes.replace('12   ', float('nan'))
df_acidentes = df_acidentes.replace('14:h ', float('nan'))

# %% [markdown]
# Após a limpeza, ambas as colunas foram convertidas para o tipo datetime

# %%
df_acidentes['hr_primeira_obs_mod'] = pd.to_datetime(df_acidentes['hr_primeira_obs'])
df_acidentes['hr_primeira_obs_mod'] = df_acidentes['hr_primeira_obs_mod'].dt.time

df_acidentes['hr_ocorrencia_mod'] = pd.to_datetime(df_acidentes['hr_ocorrencia'])
df_acidentes['hr_ocorrencia_mod'] = df_acidentes['hr_ocorrencia_mod'].dt.time
# Out:
# <ipython-input-21-91fbc143c283>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_acidentes['hr_primeira_obs_mod'] = pd.to_datetime(df_acidentes['hr_primeira_obs'])
# <ipython-input-21-91fbc143c283>:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_acidentes['hr_ocorrencia_mod'] = pd.to_datetime(df_acidentes['hr_ocorrencia'])

# %%
df_acidentes['hr_ocorrencia_mod']
# Out:
# 0             NaT
# 1        00:00:00
# 2             NaT
# 3             NaT
# 4             NaT
#            ...
# 13750    09:22:00
# 13751    17:10:00
# 13752    22:56:00
# 13753    09:55:00
# 13754    08:45:00
# Name: hr_ocorrencia_mod, Length: 13755, dtype: object

# %%
df_acidentes['hr_primeira_obs']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 13750    09:22
# 13751    16:23
# 13752    22:56
# 13753    09:55
# 13754    08:45
# Name: hr_primeira_obs, Length: 13755, dtype: object

# %% [markdown]
# Foram encontrados também casos em que a diferença entre a data de registro e a data da primeira observação é negativa, ou seja, a observação ocorreu depois do registro, o que não é possível. Nestes casos, provavelmente houve um erro na digitação da data de observação e, por isso, o valor foi transformado em NaN.

# %%
for i in range(len(df_acidentes)):
  if (type(df_acidentes['dt_primeira_obs_mod'][i])!= pd._libs.tslibs.nattype.NaTType) and (type(df_acidentes['dt_registro_mod'][i])!= pd._libs.tslibs.nattype.NaTType):
    dif = df_acidentes['dt_registro_mod'][i] - df_acidentes['dt_primeira_obs_mod'][i]
    if(dif.days < 0):
      print("data ocorrência:", df_acidentes['dt_ocorrencia_mod'][i],"\ndata obs:", df_acidentes['dt_primeira_obs_mod'][i], "\ndata registro:", df_acidentes['dt_registro_mod'][i], "\ndiferença em dias:", df_acidentes['dt_registro_mod'][i] - df_acidentes['dt_primeira_obs_mod'][i], "\n\n")

      df_acidentes.loc[i, 'dt_primeira_obs_mod'] = float('nan')
      df_acidentes.loc[i, 'dt_primeira_obs'] = float('nan')
# Out:
# data ocorrência: 2014-10-20 00:00:00
# data obs: 2015-12-20 00:00:00
# data registro: 2015-09-02 11:09:35
# diferença em dias: -109 days +11:09:35
#
#
# data ocorrência: 2018-06-01 00:00:00
# data obs: 2018-06-01 00:00:00
# data registro: 2018-02-01 16:16:10
# diferença em dias: -120 days +16:16:10
#
#
# data ocorrência: 2018-06-01 00:00:00
# data obs: 2018-06-01 00:00:00
# data registro: 2018-02-01 16:16:10
# diferença em dias: -120 days +16:16:10
#
#
# data ocorrência: 2021-06-29 00:00:00
# data obs: 2021-06-29 00:00:00
# data registro: 2021-06-09 11:23:34
# diferença em dias: -20 days +11:23:34

# %% [markdown]
# O mesmo processo foi realizado na verificação de diferença entre registro e ocorrência.

# %%
for i in range(len(df_acidentes)):
  if (type(df_acidentes['dt_ocorrencia_mod'][i])!= pd._libs.tslibs.nattype.NaTType) and (type(df_acidentes['dt_registro_mod'][i])!= pd._libs.tslibs.nattype.NaTType):
    dif = df_acidentes['dt_registro_mod'][i] - df_acidentes['dt_ocorrencia_mod'][i]
    if(dif.days < 0):
      print("data ocorrência:", df_acidentes['dt_ocorrencia_mod'][i],"\ndata obs:", df_acidentes['dt_primeira_obs_mod'][i], "\ndata registro:", df_acidentes['dt_registro_mod'][i], "\ndiferença em dias:", df_acidentes['dt_registro_mod'][i] - df_acidentes['dt_ocorrencia_mod'][i], "\n\n")

      df_acidentes.loc[i, 'dt_ocorrencia_mod'] = float('nan')
      df_acidentes.loc[i, 'dt_ocorrencia'] = float('nan')
# Out:
# data ocorrência: 2016-09-06 00:00:00
# data obs: 2016-02-06 00:00:00
# data registro: 2016-02-29 14:58:51
# diferença em dias: -190 days +14:58:51
#
#
# data ocorrência: 2018-06-01 00:00:00
# data obs: NaT
# data registro: 2018-02-01 16:16:10
# diferença em dias: -120 days +16:16:10
#
#
# data ocorrência: 2018-06-01 00:00:00
# data obs: NaT
# data registro: 2018-02-01 16:16:10
# diferença em dias: -120 days +16:16:10
#
#
# data ocorrência: 2021-06-29 00:00:00
# data obs: NaT
# data registro: 2021-06-09 11:23:34
# diferença em dias: -20 days +11:23:34

# %% [markdown]
# Após limpeza inicial: 33 colunas

# %%
df_acidentes.columns
# Out:
# Index(['dt_ocorrencia', 'hr_ocorrencia', 'dt_registro', 'plano_emergencia',
#        'plano_emergencia_acionado', 'iniciados_outras_providencias',
#        'ocorrencia_oleo', 'dt_primeira_obs', 'hr_primeira_obs',
#        'informacao_responsavel', 'des_causa_provavel', 'endereco_ocorrencia',
#        'legado', 'des_instituicao_empresa', 'validado', 'tipo_comunicado',
#        'periodo_ocorrencia', 'periodo_primeira_obs', 'municipio', 'uf',
#        'origem', 'tipo_evento', 'dt_ocorrencia_feriado',
#        'institiuicoes_atuando_local', 'tipos_fontes_informacoes',
#        'tipos_danos_identificados', 'geom', 'dt_ocorrencia_mod',
#        'dt_registro_mod', 'dt_primeira_obs_mod', 'registro_ano',
#        'hr_primeira_obs_mod', 'hr_ocorrencia_mod'],
#       dtype='object')

# %% [markdown]
# ### Visualização dos dados de data e hora

# %% [markdown]
# Após esse tratamento, podemos visualizar melhor a distribuição do número de dias entre a observação e o registro do acidente. Abaixo vemos essa distribuição considerando todos os casos.

# %%
day_count_dif = []

for i in range(len(df_acidentes)):
  if (type(df_acidentes['dt_primeira_obs_mod'][i])!= pd._libs.tslibs.nattype.NaTType) and (type(df_acidentes['dt_registro_mod'][i])!= pd._libs.tslibs.nattype.NaTType):
    dif = df_acidentes['dt_registro_mod'][i] - df_acidentes['dt_primeira_obs_mod'][i]
    day_count_dif.append((df_acidentes['dt_registro_mod'][i] - df_acidentes['dt_primeira_obs_mod'][i]).days)

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=day_count_dif, binwidth=100, kde=True)
plt.xlabel("Contagem de dias")
plt.ylabel("Número de observações")
plt.title("Dias entre primeira observação e registro")
plt.show()

# %% [markdown]
# É possível notar que existe uma minoria de casos em que a diferença entre as datas se extendem além de 5000 dias (mais de 13 anos). Não sabemos se isso se trata de um erro de registro ou um dado verdadeiro, mas podemos conferir esses números mais de perto.
#
# Abaixo separamos os dados entre aqueles que têm diferença entre as datas superior a 365 dias e os que tem diferença inferior a esse valor.

# %%
long_day_count_dif = []
short_day_count_dif = []

for i in range(len(df_acidentes)):
  if (type(df_acidentes['dt_primeira_obs_mod'][i])!= pd._libs.tslibs.nattype.NaTType) and (type(df_acidentes['dt_registro_mod'][i])!= pd._libs.tslibs.nattype.NaTType):
    dif = df_acidentes['dt_registro_mod'][i] - df_acidentes['dt_primeira_obs_mod'][i]
    if(dif.days > 365):
      long_day_count_dif.append((df_acidentes['dt_registro_mod'][i] - df_acidentes['dt_primeira_obs_mod'][i]).days)
      print("data ocorrência:", df_acidentes['dt_ocorrencia_mod'][i],"\ndata obs:", df_acidentes['dt_primeira_obs_mod'][i], "\ndata registro:", df_acidentes['dt_registro_mod'][i], "\ndiferença em dias:", df_acidentes['dt_registro_mod'][i] - df_acidentes['dt_primeira_obs_mod'][i], "\n\n")
    else:
      short_day_count_dif.append((df_acidentes['dt_registro_mod'][i] - df_acidentes['dt_primeira_obs_mod'][i]).days)
# Out:
# data ocorrência: NaT
# data obs: 2009-08-01 00:00:00
# data registro: 2021-08-20 11:40:42
# diferença em dias: 4402 days 11:40:42
#
#
# data ocorrência: NaT
# data obs: 2009-08-27 00:00:00
# data registro: 2021-08-20 11:48:42
# diferença em dias: 4376 days 11:48:42
#
#
# data ocorrência: NaT
# data obs: 2009-10-01 00:00:00
# data registro: 2021-08-20 11:54:59
# diferença em dias: 4341 days 11:54:59
#
#
# data ocorrência: NaT
# data obs: 2009-12-04 00:00:00
# data registro: 2021-08-20 12:16:19
# diferença em dias: 4277 days 12:16:19
#
#
# data ocorrência: 2013-09-30 00:00:00
# data obs: 2013-09-30 00:00:00
# data registro: 2015-11-16 16:46:55
# diferença em dias: 777 days 16:46:55
#
#
# data ocorrência: 2014-10-22 00:00:00
# data obs: 2014-10-22 00:00:00
# data registro: 2015-11-17 16:12:59
# diferença em dias: 391 days 16:12:59
#
#
# data ocorrência: 2014-07-05 00:00:00
# data obs: 2014-07-05 00:00:00
# data registro: 2016-01-13 15:30:11
# diferença em dias: 557 days 15:30:11
#
#
# ...

# %% [markdown]
# São, ao todo, 281 observações em que a diferença entre as datas ultrapassa um ano. A maior contagem de dias entre observação e registro é 5235 dias. Abaixo temos um histograma com a distribuição dos valores desses casos.

# %%
len(long_day_count_dif)
# Out:
# 281

# %%
max(long_day_count_dif)
# Out:
# 5235

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=long_day_count_dif, binwidth=200, kde=True)
plt.xlabel("Contagem de dias")
plt.ylabel("Número de observações")
plt.title("Dias entre primeira observação e registro (mais de 365 dias)")
plt.show()

# %% [markdown]
# Os casos em que a diferença de datas é menor ou igual a 365 dias somam 7435 observações.

# %%
len(short_day_count_dif)
# Out:
# 7435

# %% [markdown]
# Podemos também olhar mais de perto os casos em que o acidente foi registrado em até 15 dias após a primeira observação. Para estes casos temos 6313 observações. Abaixo temos o histograma da distribuição desses valores

# %%
very_short_day_count_dif = []
zero_day_count_dif = []
for i in range(len(df_acidentes)):
  if (type(df_acidentes['dt_primeira_obs_mod'][i])!= pd._libs.tslibs.nattype.NaTType) and (type(df_acidentes['dt_registro_mod'][i])!= pd._libs.tslibs.nattype.NaTType):
    dif = df_acidentes['dt_registro_mod'][i] - df_acidentes['dt_primeira_obs_mod'][i]
    if(dif.days <= 15):
      very_short_day_count_dif.append((df_acidentes['dt_registro_mod'][i] - df_acidentes['dt_primeira_obs_mod'][i]).days)
      if(dif.days < 1):
        zero_day_count_dif.append((df_acidentes['dt_registro_mod'][i] - df_acidentes['dt_primeira_obs_mod'][i]))

# %%
len(very_short_day_count_dif)
# Out:
# 6313

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=very_short_day_count_dif, binwidth=1, kde=True)
plt.xlabel("Contagem de dias")
plt.ylabel("Número de observações")
plt.title("Dias entre primeira observação e registro (15 dias ou menos)")
plt.show()

# %% [markdown]
# É possível notar que a maioria dos acidentes são registrados nos 4 primeiros dias após as observações.
#
# Para os acidentes registrados em menos de um dia, podemos observar a quantidade de horas que até o registro. Existem 1354 desses casos.

# %%
len(zero_day_count_dif)
# Out:
# 1354

# %%
def hours(td):
    return round(td.seconds/3600, 2)

# %%
hours_count = []
for i in zero_day_count_dif:
  hours_count.append(hours(i))

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=hours_count, binwidth=1, kde=True)

plt.xlabel("Contagem de horas")
plt.ylabel("Número de observações")
plt.title("Horas entre a observação e o registro (até 24 horas)")
plt.show()

# %% [markdown]
# ### Quantidade de registros de cada estado

# %% [markdown]
# Podemos visualizar melhor a quantidade de registros presentes na base de dados separados por estado

# %%
df_acidentes['uf'].isna().sum()
# Out:
# 953

# %%
bar_df = pd.DataFrame(df_acidentes['uf'].value_counts()).reset_index()
bar_df
# Out:
#     uf  count
# 0   MG   3474
# 1   SP   2462
# 2   RJ   2123
# 3   PR    643
# 4   BA    545
# 5   RS    509
# 6   SC    437
# 7   ES    416
# 8   SE    228
# 9   MS    216
# 10  DF    202
# 11  GO    201
# 12  CE    193
# 13  MA    157
# 14  RN    153
# 15  MT    139
# 16  AL    136
# 17  AM    131
# 18  PA    121
# 19  PE     89
# 20  TO     64
# 21  PB     49
# 22  RO     49
# 23  PI     38
# 24  AP     12
# 25  RR      9
# 26  AC      6

# %%
plt.figure(figsize=(10,6))
ax = sns.barplot(bar_df, x=bar_df['uf'], y=bar_df['count'])
plt.show()

# %% [markdown]
# Percebe-se que os três primeiros estados em número de acidentes registrados possuem uma quantidade muito maior de registros que os estados na 4° posição em diante. Futuramente, podemos olhar com mais calma as características dos dados desses três estados especificamente.

# %% [markdown]
# ### Quantidade de registros por ano

# %% [markdown]
# Da mesma forma que fizemos com os estados, podemos visualizar a quantidade de registros de cada ano presente na base de dados

# %%
bar_df2 = pd.DataFrame(df_acidentes['registro_ano'].value_counts()).reset_index()
bar_df2
# Out:
#     registro_ano  count
# 0           2010   1378
# 1           2019   1270
# 2           2011   1213
# 3           2021   1097
# 4           2012   1091
# 5           2022   1062
# 6           2018   1056
# 7           2017    914
# 8           2020    894
# 9           2009    889
# 10          2016    684
# 11          2013    623
# 12          2015    511
# 13          2023    458
# 14          2008    295
# 15          2007    172
# 16          2006    110
# 17          2014     34
# 18          2000      3
# 19          2001      1

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(bar_df2, x=bar_df2['registro_ano'], y=bar_df2['count'])
plt.xlabel("Ano")
plt.ylabel("Contagem")
plt.title("Quantidade de registros por ano")
plt.show()

# %% [markdown]
# É possível perceber que os anos 2000, 2001 e 2014 possuem números de registros muito baixos em relação aos outros anos, mesmo aqueles que possuem baixa contagem de regitros.

# %% [markdown]
# ### Contagem de ocorrência de óleo no acidente

# %% [markdown]
# A coluna "ocorrencia_oleo" registra a ocorrência ou não de vazamento de óleo no acidente em questão. Podemos visualizar melhor a contagem das respostas nessa coluna

# %%
df_acidentes['ocorrencia_oleo'].isna().sum()
# Out:
# 0

# %% [markdown]
# Não existem dados nulos na coluna em questão

# %%
bar_df3 = pd.DataFrame(df_acidentes['ocorrencia_oleo'].value_counts()).reset_index()
bar_df3
# Out:
#   ocorrencia_oleo  count
# 0               N  10890
# 1               S   2865

# %%
plt.figure(figsize=(8,5))
ax = sns.barplot(bar_df3, x=bar_df3['ocorrencia_oleo'], y=bar_df3['count'])
plt.xlabel("Resposta")
plt.ylabel("Contagem")
plt.title("Ocorrência ou não de vazamento de óleo no acidente")
plt.show()

# %% [markdown]
# ### Contagem das colunas "tipo_evento" e "tipos_danos_identificados"

# %% [markdown]
# Primeiramente, podemos identificar 145 dados nulos na coluna "tipo_evento", e 941 na coluna "tipos_danos_identificados". Talvez essa disparidade se deva ao fato de que é mais fácil averiguar o tipo de acidente do que uma lista completa dos danos sofridos.

# %%
df_acidentes['tipo_evento'].isna().sum()
# Out:
# 145

# %%
df_acidentes['tipos_danos_identificados'].isna().sum()
# Out:
# 941

# %%
df_acidentes['tipo_evento'].value_counts()
# Out:
# tipo_evento
# Outro(s)                                                                                    6578
# Derramamento de líquidos                                                                    4791
# Lançamento de sólidos                                                                        993
# Explosão/incêndio                                                                            270
# Vazamento de gases                                                                           164
# Explosão/incêndio;Outro(s)                                                                   152
# Derramamento de líquidos;Lançamento de sólidos                                               130
# Derramamento de líquidos;Explosão/incêndio                                                    98
# Produtos químicos/embalagens abandonadas                                                      70
# ...

# %%
df_acidentes['tipos_danos_identificados'].value_counts()
# Out:
# tipos_danos_identificados
# Mar                                                          3263
# Outro(s)                                                     3042
# Solo                                                         2296
# Atmosfera                                                     882
# Rio/córrego                                                   375
#                                                              ...
# Outro(s);População afetada/evacuada;Rio/córrego;Solo            1
# Fauna;Flora;Mar;Outro(s);População afetada/evacuada;Praia       1
# Fauna;Flora;Óbitos/feridos;Rio/córrego;Solo                     1
# Lago;População afetada/evacuada;Solo                            1
# Atmosfera;Flora;Óbitos/feridos;Solo                             1
# Name: count, Length: 274, dtype: int64

# %% [markdown]
# Devemos notar que os tipos de evento e de dano notificados possuem múltiplas descrições para um mesmo atributo, separadas por ponto e vírgula, e cada combinação de descrições aparece como um valor diferente, dificultando a visualização.
#
# Podemos visualizar a quantia de cada tipo de descrição separadamente. Iremos começar pelos tipos de eventos.

# %%
tipos_eventos_valores = df_acidentes['tipo_evento'].value_counts().to_dict()
ocorrencias_separadas_dicionario = {}

for valor, quantidade in tipos_eventos_valores.items():
  danos = valor.split(';')
  for dano in danos:
    ocorrencias_separadas_dicionario .setdefault(dano, 0)
    ocorrencias_separadas_dicionario[dano] += quantidade


tipos_eventos_separados = pd.DataFrame(list(ocorrencias_separadas_dicionario.items()), columns=['Evento', 'Contagem'])
tipos_eventos_separados
# Out:
#                                      Evento  Contagem
# 0                                  Outro(s)      6883
# 1                  Derramamento de líquidos      5153
# 2                     Lançamento de sólidos      1212
# 3                         Explosão/incêndio       570
# 4                        Vazamento de gases       217
# 5  Produtos químicos/embalagens abandonadas       106
# 6                      Mortandade de peixes        62
# 7                    Rompimento de barragem        56
# 8                          Desastre Natural        24

# %%
plt.figure(figsize=(15,6))
ax = sns.barplot(tipos_eventos_separados, x=tipos_eventos_separados['Evento'], y=tipos_eventos_separados['Contagem'])
ax.tick_params(axis='x', rotation=70)
plt.show()

# %% [markdown]
# O resultado ficou muito mais interpretável. Agora, para o tipo de dano:

# %%
tipos_danos_valores = df_acidentes['tipos_danos_identificados'].value_counts().to_dict()
ocorrencias_separadas_dicionario = {}

for valor, quantidade in tipos_danos_valores.items():
  danos = valor.split(';')
  for dano in danos:
    ocorrencias_separadas_dicionario .setdefault(dano, 0)
    ocorrencias_separadas_dicionario[dano] += quantidade


tipos_danos_separados = pd.DataFrame(list(ocorrencias_separadas_dicionario.items()), columns=['Dano', 'Contagem']).sort_values(by=['Contagem'], ascending=False)
tipos_danos_separados
# Out:
#                                          Dano  Contagem
# 1                                    Outro(s)      3753
# 2                                        Solo      3534
# 0                                         Mar      3442
# 3                                   Atmosfera      1603
# 4                                 Rio/córrego      1194
# 6                              Óbitos/feridos       836
# 5                                       Fauna       639
# 7                                       Flora       436
# 8                  População afetada/evacuada       335
# 9                                        Lago       175
# 10                                      Praia       138
# 12  Unidade de Conservação Estadual/Municipal        45
# 13             Unidade de Conservação Federal        41
# 11                         Águas subterrâneas        38
# 14         Suspensão de abastecimento de água        16

# %%
plt.figure(figsize=(15,6))
ax = sns.barplot(tipos_danos_separados, x=tipos_danos_separados['Dano'], y=tipos_danos_separados['Contagem'])
ax.tick_params(axis='x', rotation=70)
plt.show()

# %% [markdown]
# Depois, vamos visualizar como essas ocorrências se distribuem por estado e também por região. Já vimos a quantidade de ocorrência de cada estado, e a distribuição é bastante desigual, então devemos investigar como e por quê isso ocorre.

# %% [markdown]
# ### Derramamento de óleo por tipo de evento e tipo de dano

# %% [markdown]
# É possível que a maior parte dos acidentes que registram derramamento de óleo estejam registrados em "Derramamento de Líquidos", mas podemos também explorar quantos acidentes sob essa categoria não apresentaram derramamento de óleo.

# %%
list_derramamento = []
for index in range(len(df_acidentes)):
  if "Derramamento de líquidos" in str(df_acidentes['tipo_evento'][index]):
    list_derramamento.append("categoria derramamento de líquidos")
  else:
    list_derramamento.append("outras categorias")

df_acidentes['Derramamento de líquidos'] = list_derramamento

# %%
plt.figure(figsize=(10,6))
ax = sns.countplot(df_acidentes, x=df_acidentes['Derramamento de líquidos'], hue='ocorrencia_oleo')
plt.show()

# %% [markdown]
# Para os casos na categoria "derramamento de líquidos", podemos explorar também os outros eventos associados nos casos em que não houve ocorrência de óleo

# %%
df_derramamento = df_acidentes.loc[df_acidentes['Derramamento de líquidos']=='categoria derramamento de líquidos']
df_derramamento_sem_oleo = df_derramamento.loc[df_derramamento['ocorrencia_oleo']=='N']

# %%
evento_derramamento_sem_oleo = df_derramamento_sem_oleo['tipo_evento'].value_counts().to_dict()
ocorrencias_separadas_dicionario = {}

for valor, quantidade in evento_derramamento_sem_oleo.items():
  danos = valor.split(';')
  for dano in danos:
    ocorrencias_separadas_dicionario .setdefault(dano, 0)
    ocorrencias_separadas_dicionario[dano] += quantidade


evento_derramamento_sem_oleo_separados = pd.DataFrame(list(ocorrencias_separadas_dicionario.items()), columns=['Evento', 'Contagem'])
evento_derramamento_sem_oleo_separados
# Out:
#                                      Evento  Contagem
# 0                  Derramamento de líquidos      2663
# 1                     Lançamento de sólidos       140
# 2                         Explosão/incêndio        95
# 3                                  Outro(s)        58
# 4                        Vazamento de gases        21
# 5  Produtos químicos/embalagens abandonadas        20
# 6                      Mortandade de peixes         4
# 7                    Rompimento de barragem         2

# %% [markdown]
# De forma semelhante, podemos assumir que a maioria dos acidentes envolvendo derramamento de óleo causam danos ao mar, mas podemos visualizar também a quantidade de ocorrências em que os danos ao mar foram causados por outros fatores

# %%
list_danos_mar = []
for index in range(len(df_acidentes)):
  if "Mar" in str(df_acidentes['tipos_danos_identificados'][index]):
    list_danos_mar.append("categoria danos ao mar")
  else:
    list_danos_mar.append("outras categorias")

df_acidentes['Danos ao mar'] = list_danos_mar

# %%
plt.figure(figsize=(10,6))
ax = sns.countplot(df_acidentes, x=df_acidentes['Danos ao mar'], hue='ocorrencia_oleo')
plt.show()

# %% [markdown]
# Para os casos na categoria de danos ao mar, podemos explorar também os outros eventos associados nos casos em que não houve ocorrência de óleo

# %%
df_danos_mar = df_acidentes.loc[df_acidentes['Danos ao mar']=='categoria danos ao mar']
df_danos_mar_sem_oleo = df_danos_mar.loc[df_danos_mar['ocorrencia_oleo']=='N']

# %%
evento_danos_mar_sem_oleo = df_danos_mar_sem_oleo['tipos_danos_identificados'].value_counts().to_dict()
ocorrencias_separadas_dicionario = {}

for valor, quantidade in evento_danos_mar_sem_oleo.items():
  danos = valor.split(';')
  for dano in danos:
    ocorrencias_separadas_dicionario .setdefault(dano, 0)
    ocorrencias_separadas_dicionario[dano] += quantidade


evento_danos_mar_sem_oleo_separados = pd.DataFrame(list(ocorrencias_separadas_dicionario.items()), columns=['Evento', 'Contagem'])
evento_danos_mar_sem_oleo_separados
# Out:
#                                        Evento  Contagem
# 0                                         Mar      1282
# 1                                       Praia        47
# 2                                    Outro(s)        24
# 3                                       Fauna        36
# 4                                        Solo        12
# 5                                   Atmosfera         8
# 6                                       Flora         9
# 7                              Óbitos/feridos        11
# 8                                 Rio/córrego         9
# 9                  População afetada/evacuada         9
# 10             Unidade de Conservação Federal         1
# 11  Unidade de Conservação Estadual/Municipal         1
# 12                                       Lago         1

# %% [markdown]
# ### Tratamento da coluna de coordenadas

# %% [markdown]
# Após algumas tentativas de plotar gráficos com pontos referentes às coordenadas da coluna "geom", chegamos à conclusão de que uma ou mais coordenadas estariam causando problemas na plotagem. Para descubrir exatamente onde estava o erro, fizemos algumas buscas pelo dataset

# %%
df_acidentes['geom']
# Out:
# 0                   POINT (-35.9511275 -9.6016711)
# 1                  POINT (-40.3016327 -20.2996826)
# 2                   POINT (-54.812208 -22.2206145)
# 3                    POINT (-47.9768478 -15.82326)
# 4                    POINT (-52.097268 -29.331113)
#                            ...
# 13750    POINT (-44.378622192889 -2.5526698867722)
# 13751    POINT (-43.119744742289 -22.880162025914)
# 13752    POINT (-42.511656666667 -24.609763611111)
# 13753       POINT (-36.97602186352 -10.6499725112)
# 13754          POINT (-42.707801111111 -24.811395)
# Name: geom, Length: 13755, dtype: object

# %% [markdown]
# Depois de realizar as buscas, encontramos a coordenada que estava causando erros e retiramos ela do dataset.

# %%
lat_list = []
lon_list = []
for i in range(len(df_acidentes)):
  coord = df_acidentes['geom'][i][7:-1].split(" ")
  lon_list.append(float(coord[0]))
  lat_list.append(float(coord[1]))

df_acidentes['lat'] = lat_list
df_acidentes['lon'] = lon_list

# %%
df_acidentes['geom'][9033]
# Out:
# 'POINT (-46.296182870865 -23.971548271218)'

# %%
df_acidentes_geom = df_acidentes.drop(9032)

# %% [markdown]
# ### Visualização de dados por localização

# %%
fig = px.scatter_map(df_acidentes_geom, lat="lat", lon="lon", hover_name="tipo_evento",color='ocorrencia_oleo', map_style="open-street-map")
fig.update_layout(margin={"r":0,"t":50,"l":0,"b":0})
fig.update_layout(title = 'Localização dos acidentes (geral)')
fig.update_layout(
    autosize=False,
    width=1100,
    height=600,
    margin=dict(
        l=10,
        r=10,
        b=10,
        t=50,
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_anos = []
for ano in range (2006, 2024):
  df_anos.append(df_acidentes_geom.loc[df_acidentes_geom['registro_ano']==ano])

# %%
import plotly.graph_objects as go

fig = go.Figure()

ano = 2006

for i in range(len(df_anos)):
  fig.add_trace(go.Scattermap(mode="markers",
                              lat = df_anos[i]['lat'],
                              lon = df_anos[i]['lon'],
                              hovertext=df_anos[i]['tipo_evento'],
                              marker = {'color':'blue'}))

fig.update_layout(
  updatemenus = [
      dict(active=0,
          buttons=list([
              dict(label = "All",
                  method = "update",
                  args= [{"visible": [True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True]}]
                   ),
              dict(label = "2006",
                  method = "update",
                  args= [{"visible": [True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]}]
                   ),
              dict(label = "2007",
                  method = "update",
                  args= [{"visible": [False,True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]}]
                  ),
              dict(label = "2008",
                  method = "update",
                  args= [{"visible": [False,False,True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]}]
                   ),
              dict(label = "2009",
                  method = "update",
                  args= [{"visible": [False,False,False,True,False,False,False,False,False,False,False,False,False,False,False,False,False,False]}]
                  ),
              dict(label = "2010",
                  method = "update",
                  args= [{"visible": [False,False,False,False,True,False,False,False,False,False,False,False,False,False,False,False,False,False]}]
                   ),
              dict(label = "2011",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,True,False,False,False,False,False,False,False,False,False,False,False,False]}]
                  ),
              dict(label = "2012",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,True,False,False,False,False,False,False,False,False,False,False,False]}]
                   ),
              dict(label = "2013",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,True,False,False,False,False,False,False,False,False,False,False]}]
                  ),
              dict(label = "2014",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,True,False,False,False,False,False,False,False,False,False]}]
                   ),
              dict(label = "2015",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,True,False,False,False,False,False,False,False,False]}]
                  ),
              dict(label = "2016",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,True,False,False,False,False,False,False,False]}]
                   ),
              dict(label = "2017",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,True,False,False,False,False,False,False]}]
                  ),
              dict(label = "2018",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,False,True,False,False,False,False,False]}]
                   ),
              dict(label = "2019",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,False,False,True,False,False,False,False]}]
                  ),
              dict(label = "2020",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,False,False,False,True,False,False,False]}]
                  ),
              dict(label = "2021",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True,False,False]}]
                   ),
              dict(label = "2022",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True,False]}]
                  ),
              dict(label = "2023",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True]}]
                  )
              ])
          )],
  map = {'style': "open-street-map",
         'pitch': 0},
  margin={"r":0,"t":50,"l":0,"b":0},
  showlegend=False
  )

fig.update_layout(
    autosize=False,
    width=1100,
    height=600,
    margin=dict(
        l=10,
        r=10,
        b=10,
        t=50,
    )
)

fig.update_layout(
    title=dict(
        text="Distribuição geográfica de acidentes"
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Por meio do mapa, é possível observar um padrão: os pontos tendem a formar desenhos de "linhas", e essas linhas correspondem a rodovias que ligam as principais cidades do Brasil. Seria interessante aplicar um método de clusterização binária que separasse essas ocorrências das demais, possibilitando uma análise comparativa.
#
# Propomos um método ad-hoc que funciona da seguinte maneira: dado o conjunto de pontos no mapa, e dois hiperparâmetros $min\_viz$ e $min\_dist$, insere no cluster $R$ de pontos das rodovias os pontos para os quais há pelo menos outros $min\_viz$ pontos num raio de $min\_dist$, e os demais são inseridos no cluster $F$, de pontos de fora das rodovias.
#
# (Caso fique muito demorado, eu vou otimizar separando os pontos em quadrados de tamanho $tamanho\_quadrado$ no plano do mapa, e comparar apenas pontos que estão no mesmo quadrado)

# %%
def pontos_rodovias(pontos, min_dist, min_viz):

  # Usaremos as coordenadas de latitude e longitude para calcular a distância
  coords = pontos[['lat', 'lon']].to_numpy()

  # Passo 2: Calculando a matriz de distâncias euclidianas
  distances = np.linalg.norm(coords[:, None, :] - coords[None, :, :], axis=2)

  # Passo 3: Contando quantos pontos estão dentro da distância `min_dist`
  neighbors_count = np.sum(distances <= min_dist, axis=1) - 1  # Exclui a própria linha

  # Passo 4: Criando duas máscaras booleanas
  valid_rows = neighbors_count >= min_viz  # Linhas que atendem ao critério
  invalid_rows = ~valid_rows          # Linhas que não atendem

  # Passo 5: Separando os dataframes
  R = df[valid_rows]
  F = df[invalid_rows]

  return R, F

# %% [markdown]
# Em seguida, vamos fazer o plot do gráfico acima, porém usando cores diferentes para pontos de clusters diferentes.

# %%
df_acidentes_geom_R, df_acidentes_geom_F = pontos_rodovias(df_acidentes_geom, 0.7, 4)

df_anos_R = []
df_anos_F = []
for ano in range (2006, 2024):
  df_anos_R.append(df_acidentes_geom.loc[df_acidentes_geom_R['registro_ano']==ano])
  df_anos_F.append(df_acidentes_geom.loc[df_acidentes_geom_F['registro_ano']==ano])

fig = go.Figure()

ano = 2006

for i in range(len(df_anos)):
  fig.add_trace(go.Scattermap(mode="markers",
                              lat = df_anos[i]['lat'],
                              lon = df_anos[i]['lon'],
                              hovertext=df_anos_R[i]['tipo_evento'],
                              marker = {'color':'green'}))
  fig.add_trace(go.Scattermap(mode="markers",
                              lat = df_anos[i]['lat'],
                              lon = df_anos[i]['lon'],
                              hovertext=df_anos_F[i]['tipo_evento'],
                              marker = {'color':'red'}))

fig.update_layout(
  updatemenus = [
      dict(active=0,
          buttons=list([
              dict(label = "All",
                  method = "update",
                  args= [{"visible": [True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True]}]
                   ),
              dict(label = "2006",
                  method = "update",
                  args= [{"visible": [True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]}]
                   ),
              dict(label = "2007",
                  method = "update",
                  args= [{"visible": [False,True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]}]
                  ),
              dict(label = "2008",
                  method = "update",
                  args= [{"visible": [False,False,True,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False]}]
                   ),
              dict(label = "2009",
                  method = "update",
                  args= [{"visible": [False,False,False,True,False,False,False,False,False,False,False,False,False,False,False,False,False,False]}]
                  ),
              dict(label = "2010",
                  method = "update",
                  args= [{"visible": [False,False,False,False,True,False,False,False,False,False,False,False,False,False,False,False,False,False]}]
                   ),
              dict(label = "2011",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,True,False,False,False,False,False,False,False,False,False,False,False,False]}]
                  ),
              dict(label = "2012",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,True,False,False,False,False,False,False,False,False,False,False,False]}]
                   ),
              dict(label = "2013",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,True,False,False,False,False,False,False,False,False,False,False]}]
                  ),
              dict(label = "2014",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,True,False,False,False,False,False,False,False,False,False]}]
                   ),
              dict(label = "2015",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,True,False,False,False,False,False,False,False,False]}]
                  ),
              dict(label = "2016",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,True,False,False,False,False,False,False,False]}]
                   ),
              dict(label = "2017",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,True,False,False,False,False,False,False]}]
                  ),
              dict(label = "2018",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,False,True,False,False,False,False,False]}]
                   ),
              dict(label = "2019",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,False,False,True,False,False,False,False]}]
                  ),
              dict(label = "2020",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,False,False,False,True,False,False,False]}]
                  ),
              dict(label = "2021",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True,False,False]}]
                   ),
              dict(label = "2022",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True,False]}]
                  ),
              dict(label = "2023",
                  method = "update",
                  args= [{"visible": [False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True]}]
                  )
              ])
          )],
  map = {'style': "open-street-map",
         'pitch': 0},
  margin={"r":0,"t":50,"l":0,"b":0},
  showlegend=False
  )

fig.update_layout(
    autosize=False,
    width=1100,
    height=600,
    margin=dict(
        l=10,
        r=10,
        b=10,
        t=50,
    )
)

fig.update_layout(
    title=dict(
        text="Distribuição geográfica de acidentes (segmentando os acidentes das áreas mais frequentes)"
    )
)

fig.show()

# %% [markdown]
# Outra ideia possível: fazer outra clusterização dentro de $R$ para separar pontos dentro das cidades grandes de pontos nas rodovias.
